# %% [markdown]
# <a href="https://colab.research.google.com/github/jeongiggyun/yolov8/blob/main/yolov8_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# colab 환경설정

# %%
# !pip install ultralytics
# !pip install opencv-python
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 11.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# 모델 로드

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # COCO dataset으로 pretrained된 모델을 불러옴
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 56.4MB/s]

# %% [markdown]
# 이미지 업로드

# %%
from google.colab import files

uploaded = files.upload()
image_path = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-7c62847d-fd90-4536-83c8-72bae62caf8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c62847d-fd90-4536-83c8-72bae62caf8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 객체 인식 수행

# %%
results = model(image_path)  # 직접 모델을 호출하여 객체 인식 수행
# Out:
# image 1/1 /content/OIP.jpg: 448x640 2 cars, 1 traffic light, 281.5ms
# Speed: 12.8ms preprocess, 281.5ms inference, 24.7ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# 결과 시각화

# %%
results[0].plot()
# Out:
# array([[[236, 233, 225],
#         [236, 233, 225],
#         [236, 233, 225],
#         ...,
#         [226, 210, 193],
#         [226, 210, 193],
#         [226, 210, 194]],
#
#        [[231, 228, 220],
#         [231, 228, 220],
#         [231, 228, 220],
#         ...,
#         [220, 204, 187],
#         [220, 204, 187],
#         [220, 204, 188]],
#
#        [[228, 225, 217],
#         [228, 225, 217],
#         [229, 226, 218],
#         ...,
#         [221, 205, 188],
#         [221, 205, 188],
#         [221, 205, 189]],
#
#        ...,
#
#        [[ 88,  90, 120],
#         [ 89,  91, 121],
#         [ 91,  93, 123],
#         ...,
#         [121, 121, 121],
#         [120, 120, 120],
#         [120, 118, 118]],
#
#        [[106, 108, 138],
#         [105, 107, 137],
#         [103, 105, 135],
#         ...,
#         [120, 120, 120],
#         [117, 117, 117],
#         [120, 118, 118]],
#
#        [[119, 121, 151],
#         [117, 119, 149],
#         [113, 115, 145],
# ...
