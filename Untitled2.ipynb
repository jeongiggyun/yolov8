# %% [markdown]
# <a href="https://colab.research.google.com/github/jeongiggyun/yolov8/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# yolov8

# %%
# YOLOv8 설치
# !pip install ultralytics

# 필요한 라이브러리 임포트
from ultralytics import YOLO
from google.colab import files
import cv2
import numpy as np
from PIL import Image
import io
from IPython.display import display

# %% [markdown]
# 모델 로드

# %%
# YOLOv8 모델 로드
model = YOLO('yolov8n.pt')  # 'n'은 가장 작은 모델

# %% [markdown]
# 이미지 로드

# %%
# 이미지 업로드
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9518dc73-462f-4d65-9c1a-f1dab3156733" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9518dc73-462f-4d65-9c1a-f1dab3156733">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 이미지 처리 및 객체 감지

# %%
# 업로드된 각 이미지에 대해 객체 감지 수행
for filename in uploaded.keys():
    # 이미지 읽기
    image = Image.open(io.BytesIO(uploaded[filename]))

    # 이미지를 numpy 배열로 변환
    image_np = np.array(image)

    # RGB에서 BGR로 변환 (OpenCV는 BGR 사용)
    if len(image_np.shape) == 3 and image_np.shape[2] == 3:
        image_np = cv2.cvtColor(image_np, cv2.COLOR_RGB2BGR)

    # 객체 감지 실행
    results = model(image_np)
# Out:
# 0: 480x640 6 cars, 2 buss, 1 fire hydrant, 269.8ms
# Speed: 9.6ms preprocess, 269.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# 결과 시각화 및 표시

# %%
    # 결과 이미지 생성
    result_image = results[0].plot()

    # 결과 이미지를 RGB로 변환 (Colab에서 표시하기 위해)
    result_image_rgb = cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB)

    # 결과 표시
    display(Image.fromarray(result_image_rgb))
# Out:
# <PIL.Image.Image image mode=RGB size=259x194>
